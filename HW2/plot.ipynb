# %%
import matplotlib.pyplot as plt

# %%
## Non-Pretrained
# loss = [64821.6171875/27643, 59942.7265625/27643, 57978.19921875/27643, 56208.8828125/27643, 54512.4140625/27643]
# em = [4.021, 4.619, 5.782, 6.447, 6.846]
loss = [13793.0088/27643, 5724.2588/27643, 2984.1504/27643, 1598.1135/27643, 882.1193/27643]
em = [77.401, 79.029, 79.096, 79.8936, 79.661]
fig, ax = plt.subplots(figsize=(6, 4))
ax2 = ax.twinx()

ax.set_title("Pretrained")
ax.plot(loss, label = 'Loss', color='orange', linestyle="--", marker='o')
ax.plot([], label = 'EM', color='blue', linestyle="--", marker='o')
ax.set_ylabel('Loss')
ax2.plot(em, label='EM', color='blue', linestyle="--", marker='o', )
ax2.set_ylabel('EM')
ax.grid(True)
ax.legend(loc='center right')
